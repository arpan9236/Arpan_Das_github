# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset_df = pd.read_csv('Uzbekistan_tour_expenses.csv')

dataset_df
# Out:
#                                                  Cause Date      Cost  \
# 0              Flight ticket from Bangalore to Urgench  NaN  67408.00
# 1              Flight ticket from Urgench to Bangalore  NaN  70038.92
# 2                              Travel Adaptor purchase  NaN    499.00
# 3                                   Burger at Airport   NaN   1093.00
# 4                                 US Dollars purchase   NaN  29000.00
# ..                                                 ...  ...       ...
# 97   From second last day UrSU payment, for travel,...  NaN       NaN
# 98                                                 NaN  NaN       NaN
# 99   Got from UrSU at the last day = (1500 USD) + (...  NaN       NaN
# 100                                                NaN  NaN       NaN
# 101  Got 140 USD from Tashkent airport in exchange ...  NaN       NaN
#
#     Whose cost Currency  Arpan Paid Ritam Paid
# 0            B      INR        0.00  67,408.00
# ...

# %%
dataset_df.tail(9).index
# Out:
# RangeIndex(start=93, stop=102, step=1)

# %%
dataset_df.drop(dataset_df.tail(9).index, inplace = True)

dataset_df
# Out:
#                                        Cause    Date       Cost Whose cost  \
# 0    Flight ticket from Bangalore to Urgench     NaN   67408.00          B
# 1    Flight ticket from Urgench to Bangalore     NaN   70038.92          B
# 2                    Travel Adaptor purchase     NaN     499.00          B
# 3                         Burger at Airport      NaN    1093.00          B
# 4                       US Dollars purchase      NaN   29000.00          B
# ..                                       ...     ...        ...        ...
# 88                  2 cakes @ Tahskent Bazar  19/May   10000.00          B
# 89  Ritam bought 3 dresses at Tashkent bazar  19/May  310000.00          R
# 90       Tashkent bazar to rail station car   19/May   37000.00          B
# 91                 Dinner @ Tashkent station  19/May   70000.00          B
# 92           Tashkent station to Airport car  19/May   30000.00          B
#
#    Currency  Arpan Paid Ritam Paid
# ...

# %%
dataset_df.isnull().sum()
# Out:
# Cause          6
# Date          17
# Cost           9
# Whose cost    10
# Currency       9
# Arpan Paid    85
# Ritam Paid     9
# dtype: int64

# %%
dataset_df.dropna(subset = 'Cause', inplace = True)

dataset_df
# Out:
#                                        Cause    Date       Cost Whose cost  \
# 0    Flight ticket from Bangalore to Urgench     NaN   67408.00          B
# 1    Flight ticket from Urgench to Bangalore     NaN   70038.92          B
# 2                    Travel Adaptor purchase     NaN     499.00          B
# 3                         Burger at Airport      NaN    1093.00          B
# 4                       US Dollars purchase      NaN   29000.00          B
# ..                                       ...     ...        ...        ...
# 88                  2 cakes @ Tahskent Bazar  19/May   10000.00          B
# 89  Ritam bought 3 dresses at Tashkent bazar  19/May  310000.00          R
# 90       Tashkent bazar to rail station car   19/May   37000.00          B
# 91                 Dinner @ Tashkent station  19/May   70000.00          B
# 92           Tashkent station to Airport car  19/May   30000.00          B
#
#    Currency  Arpan Paid Ritam Paid
# ...

# %%
dataset_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 87 entries, 0 to 92
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Cause       87 non-null     object
#  1   Date        76 non-null     object
#  2   Cost        84 non-null     float64
#  3   Whose cost  83 non-null     object
#  4   Currency    84 non-null     object
#  5   Arpan Paid  8 non-null      float64
#  6   Ritam Paid  84 non-null     object
# dtypes: float64(2), object(5)
# memory usage: 5.4+ KB

# %%
dataset_df.isnull().sum()
# Out:
# Cause          0
# Date          11
# Cost           3
# Whose cost     4
# Currency       3
# Arpan Paid    79
# Ritam Paid     3
# dtype: int64

# %%
dataset_df['Cost'] = dataset_df['Cost'].fillna(0)

# %%
dataset_df.isnull().sum()
# Out:
# Cause          0
# Date          11
# Cost           0
# Whose cost     4
# Currency       3
# Arpan Paid    79
# Ritam Paid     3
# dtype: int64

# %%
dataset_df.groupby('Whose cost').sum()['Cost']
# Out:
# Whose cost
# A     320000.00
# B    8585617.92
# R     440000.00
# Name: Cost, dtype: float64
